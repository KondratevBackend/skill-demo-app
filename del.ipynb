# %%
from enum import StrEnum


class PaymentStatusType(StrEnum):
    pending = "pending"
    succeeded = "succeeded"
    waiting_for_capture = "waiting_for_capture"
    canceled = "canceled"
    

failed = "canceled"
print(PaymentStatusType(failed) == failed)
# Out:
# False
